# %% [markdown]
# ## Implementar em Python uma fila M/M/1.

# %% [markdown]
# - Execute a simulação da fila M/M/1 gerando N clientes (N=10^3): <br>
#   - taxa de entrada: λ=9 clientes por segundo.
#   - taxa de serviço: μ=10 clientes por segundo.
#
# - Calcule o tempo de espera na fila para cada cliente.
#
# - Essa série de tempos de espera na fila será a nossa série Xi para aplicar a heurística MSER-5Y.
#
# - Encontre o ponto de truncagem dessa simulação.
#
# - Caso necessário, continuar a simulação para valores maiores que N.

# %%
import random                      
import simpy # biblioteca de simulação
import math

# %%
taxaEntrada = 0.09           # taxa de entrada: λ=9 clientes por segundo. 
taxaServico = 0.10           # taxa de serviço: μ=10 clientes por segundo.
nClientes = 1000             # N clientes (N=10^3)

# %%
clientes = []

def chegadas(env):
    cont = 0
    i = 0
    for i in range(nClientes):
        cont +=1
        yield env.timeout(random.expovariate(1.0/taxaEntrada))
        print('--> Chegada do cliente %d no tempo %.1f' % (cont, env.now))
        env.process(atendimentoServidor(env, "cliente %d" % cont, servidorRes))

# %%
def atendimentoServidor(env, nome, servidorRes):
    request = servidorRes.request()
    yield request                       
    print('▲ Servidor inicia o atendimento do %s no tempo %.1f' % (nome, env.now))
    yield env.timeout(random.expovariate(1.0/taxaServico))
    print('▼ Servidor termina o atendimento do %s no tempo %.1f' % (nome, env.now))
    yield servidorRes.release(request)

# %%
random.seed(25)
env = simpy.Environment()
servidorRes = simpy.Resource(env, capacity=1)
env.process(chegadas(env)) 
env.run()
# Out:
# --> Chegada do cliente 1 no tempo 0.0
# ▲ Servidor inicia o atendimento do cliente 1 no tempo 0.0
# ▼ Servidor termina o atendimento do cliente 1 no tempo 0.2
# --> Chegada do cliente 2 no tempo 0.3
# ▲ Servidor inicia o atendimento do cliente 2 no tempo 0.3
# --> Chegada do cliente 3 no tempo 0.3
# --> Chegada do cliente 4 no tempo 0.4
# --> Chegada do cliente 5 no tempo 0.4
# ▼ Servidor termina o atendimento do cliente 2 no tempo 0.5
# ▲ Servidor inicia o atendimento do cliente 3 no tempo 0.5
# ▼ Servidor termina o atendimento do cliente 3 no tempo 0.5
# ▲ Servidor inicia o atendimento do cliente 4 no tempo 0.5
# ▼ Servidor termina o atendimento do cliente 4 no tempo 0.5
# ▲ Servidor inicia o atendimento do cliente 5 no tempo 0.5
# ▼ Servidor termina o atendimento do cliente 5 no tempo 0.6
# --> Chegada do cliente 6 no tempo 0.7
# ▲ Servidor inicia o atendimento do cliente 6 no tempo 0.7
# ▼ Servidor termina o atendimento do cliente 6 no tempo 0.7
# --> Chegada do cliente 7 no tempo 0.7
# ▲ Servidor inicia o atendimento do cliente 7 no tempo 0.7
# --> Chegada do cliente 8 no tempo 0.9
# --> Chegada do cliente 9 no tempo 0.9
# ▼ Servidor termina o atendimento do cliente 7 no tempo 0.9
# ▲ Servidor inicia o atendimento do cliente 8 no tempo 0.9
# ▼ Servidor termina o atendimento do cliente 8 no tempo 1.0
# ▲ Servidor inicia o atendimento do cliente 9 no tempo 1.0
# --> Chegada do cliente 10 no tempo 1.1
# --> Chegada do cliente 11 no tempo 1.1
# --> Chegada do cliente 12 no tempo 1.1
# --> Chegada do cliente 13 no tempo 1.2
# --> Chegada do cliente 14 no tempo 1.2
# ▼ Servidor termina o atendimento do cliente 9 no tempo 1.2
# ▲ Servidor inicia o atendimento do cliente 10 no tempo 1.2
# ▼ Servidor termina o atendimento do cliente 10 no tempo 1.3
# ▲ Servidor inicia o atendimento do cliente 11 no tempo 1.3
# ▼ Servidor termina o atendimento do cliente 11 no tempo 1.3
# ▲ Servidor inicia o atendimento do cliente 12 no tempo 1.3
# ▼ Servidor termina o atendimento do cliente 12 no tempo 1.4
# ▲ Servidor inicia o atendimento do cliente 13 no tempo 1.4
# ▼ Servidor termina o atendimento do cliente 13 no tempo 1.5
# ▲ Servidor inicia o atendimento do cliente 14 no tempo 1.5
# ▼ Servidor termina o atendimento do cliente 14 no tempo 1.5
# --> Chegada do cliente 15 no tempo 1.5
# ▲ Servidor inicia o atendimento do cliente 15 no tempo 1.5
# --> Chegada do cliente 16 no tempo 1.5
# --> Chegada do cliente 17 no tempo 1.5
# ▼ Servidor termina o atendimento do cliente 15 no tempo 1.6
# ▲ Servidor inicia o atendimento do cliente 16 no tempo 1.6
# --> Chegada do cliente 18 no tempo 1.6
# --> Chegada do cliente 19 no tempo 1.6
# ▼ Servidor termina o atendimento do cliente 16 no tempo 1.6
# ▲ Servidor inicia o atendimento do cliente 17 no tempo 1.6
# ▼ Servidor termina o atendimento do cliente 17 no tempo 1.6
# ▲ Servidor inicia o atendimento do cliente 18 no tempo 1.6
# ▼ Servidor termina o atendimento do cliente 18 no tempo 1.7
# ▲ Servidor inicia o atendimento do cliente 19 no tempo 1.7
# --> Chegada do cliente 20 no tempo 1.8
# --> Chegada do cliente 21 no tempo 1.8
# ▼ Servidor termina o atendimento do cliente 19 no tempo 1.8
# ▲ Servidor inicia o atendimento do cliente 20 no tempo 1.8
# --> Chegada do cliente 22 no tempo 1.9
# ▼ Servidor termina o atendimento do cliente 20 no tempo 1.9
# ▲ Servidor inicia o atendimento do cliente 21 no tempo 1.9
# --> Chegada do cliente 23 no tempo 1.9
# ▼ Servidor termina o atendimento do cliente 21 no tempo 2.0
# ▲ Servidor inicia o atendimento do cliente 22 no tempo 2.0
# --> Chegada do cliente 24 no tempo 2.0
# --> Chegada do cliente 25 no tempo 2.0
# ▼ Servidor termina o atendimento do cliente 22 no tempo 2.1
# ▲ Servidor inicia o atendimento do cliente 23 no tempo 2.1
# ▼ Servidor termina o atendimento do cliente 23 no tempo 2.1
# ▲ Servidor inicia o atendimento do cliente 24 no tempo 2.1
# ▼ Servidor termina o atendimento do cliente 24 no tempo 2.1
# ▲ Servidor inicia o atendimento do cliente 25 no tempo 2.1
# ▼ Servidor termina o atendimento do cliente 25 no tempo 2.1
# --> Chegada do cliente 26 no tempo 2.2
# ▲ Servidor inicia o atendimento do cliente 26 no tempo 2.2
# ▼ Servidor termina o atendimento do cliente 26 no tempo 2.3
# --> Chegada do cliente 27 no tempo 2.3
# ▲ Servidor inicia o atendimento do cliente 27 no tempo 2.3
# --> Chegada do cliente 28 no tempo 2.4
# ▼ Servidor termina o atendimento do cliente 27 no tempo 2.4
# ▲ Servidor inicia o atendimento do cliente 28 no tempo 2.4
# --> Chegada do cliente 29 no tempo 2.4
# --> Chegada do cliente 30 no tempo 2.4
# --> Chegada do cliente 31 no tempo 2.4
# --> Chegada do cliente 32 no tempo 2.4
# --> Chegada do cliente 33 no tempo 2.4
# ▼ Servidor termina o atendimento do cliente 28 no tempo 2.5
# ▲ Servidor inicia o atendimento do cliente 29 no tempo 2.5
# --> Chegada do cliente 34 no tempo 2.6
# --> Chegada do cliente 35 no tempo 2.7
# ▼ Servidor termina o atendimento do cliente 29 no tempo 2.7
# ▲ Servidor inicia o atendimento do cliente 30 no tempo 2.7
# ▼ Servidor termina o atendimento do cliente 30 no tempo 2.7
# ▲ Servidor inicia o atendimento do cliente 31 no tempo 2.7
# --> Chegada do cliente 36 no tempo 2.7
# --> Chegada do cliente 37 no tempo 2.7
# --> Chegada do cliente 38 no tempo 2.8
# --> Chegada do cliente 39 no tempo 2.8
# --> Chegada do cliente 40 no tempo 2.9
# --> Chegada do cliente 41 no tempo 3.0
# ▼ Servidor termina o atendimento do cliente 31 no tempo 3.0
# ▲ Servidor inicia o atendimento do cliente 32 no tempo 3.0
# ▼ Servidor termina o atendimento do cliente 32 no tempo 3.0
# ▲ Servidor inicia o atendimento do cliente 33 no tempo 3.0
# --> Chegada do cliente 42 no tempo 3.0
# ▼ Servidor termina o atendimento do cliente 33 no tempo 3.1
# ▲ Servidor inicia o atendimento do cliente 34 no tempo 3.1
# --> Chegada do cliente 43 no tempo 3.1
# --> Chegada do cliente 44 no tempo 3.2
# --> Chegada do cliente 45 no tempo 3.2
# ▼ Servidor termina o atendimento do cliente 34 no tempo 3.2
# ▲ Servidor inicia o atendimento do cliente 35 no tempo 3.2
# ▼ Servidor termina o atendimento do cliente 35 no tempo 3.2
# ▲ Servidor inicia o atendimento do cliente 36 no tempo 3.2
# ▼ Servidor termina o atendimento do cliente 36 no tempo 3.4
# ▲ Servidor inicia o atendimento do cliente 37 no tempo 3.4
# ▼ Servidor termina o atendimento do cliente 37 no tempo 3.4
# ▲ Servidor inicia o atendimento do cliente 38 no tempo 3.4
# --> Chegada do cliente 46 no tempo 3.6
# ▼ Servidor termina o atendimento do cliente 38 no tempo 3.6
# ▲ Servidor inicia o atendimento do cliente 39 no tempo 3.6
# ▼ Servidor termina o atendimento do cliente 39 no tempo 3.7
# ▲ Servidor inicia o atendimento do cliente 40 no tempo 3.7
# --> Chegada do cliente 47 no tempo 3.7
# --> Chegada do cliente 48 no tempo 3.7
# --> Chegada do cliente 49 no tempo 3.7
# ▼ Servidor termina o atendimento do cliente 40 no tempo 3.8
# ▲ Servidor inicia o atendimento do cliente 41 no tempo 3.8
# ▼ Servidor termina o atendimento do cliente 41 no tempo 3.8
# ▲ Servidor inicia o atendimento do cliente 42 no tempo 3.8
# ▼ Servidor termina o atendimento do cliente 42 no tempo 3.8
# ▲ Servidor inicia o atendimento do cliente 43 no tempo 3.8
# --> Chegada do cliente 50 no tempo 3.8
# --> Chegada do cliente 51 no tempo 3.9
# --> Chegada do cliente 52 no tempo 3.9
# ▼ Servidor termina o atendimento do cliente 43 no tempo 4.0
# ▲ Servidor inicia o atendimento do cliente 44 no tempo 4.0
# --> Chegada do cliente 53 no tempo 4.0
# ▼ Servidor termina o atendimento do cliente 44 no tempo 4.0
# ▲ Servidor inicia o atendimento do cliente 45 no tempo 4.0
# ▼ Servidor termina o atendimento do cliente 45 no tempo 4.0
# ▲ Servidor inicia o atendimento do cliente 46 no tempo 4.0
# --> Chegada do cliente 54 no tempo 4.2
# --> Chegada do cliente 55 no tempo 4.3
# --> Chegada do cliente 56 no tempo 4.3
# ▼ Servidor termina o atendimento do cliente 46 no tempo 4.3
# ▲ Servidor inicia o atendimento do cliente 47 no tempo 4.3
# --> Chegada do cliente 57 no tempo 4.3
# --> Chegada do cliente 58 no tempo 4.4
# --> Chegada do cliente 59 no tempo 4.4
# --> Chegada do cliente 60 no tempo 4.5
# --> Chegada do cliente 61 no tempo 4.5
# --> Chegada do cliente 62 no tempo 4.5
# --> Chegada do cliente 63 no tempo 4.6
# ▼ Servidor termina o atendimento do cliente 47 no tempo 4.6
# ▲ Servidor inicia o atendimento do cliente 48 no tempo 4.6
# ▼ Servidor termina o atendimento do cliente 48 no tempo 4.7
# ▲ Servidor inicia o atendimento do cliente 49 no tempo 4.7
# --> Chegada do cliente 64 no tempo 4.7
# ▼ Servidor termina o atendimento do cliente 49 no tempo 4.7
# ▲ Servidor inicia o atendimento do cliente 50 no tempo 4.7
# --> Chegada do cliente 65 no tempo 4.9
# --> Chegada do cliente 66 no tempo 4.9
# --> Chegada do cliente 67 no tempo 4.9
# ▼ Servidor termina o atendimento do cliente 50 no tempo 5.0
# ▲ Servidor inicia o atendimento do cliente 51 no tempo 5.0
# ▼ Servidor termina o atendimento do cliente 51 no tempo 5.0
# ▲ Servidor inicia o atendimento do cliente 52 no tempo 5.0
# ▼ Servidor termina o atendimento do cliente 52 no tempo 5.0
# ▲ Servidor inicia o atendimento do cliente 53 no tempo 5.0
# --> Chegada do cliente 68 no tempo 5.1
# --> Chegada do cliente 69 no tempo 5.1
# ▼ Servidor termina o atendimento do cliente 53 no tempo 5.2
# ▲ Servidor inicia o atendimento do cliente 54 no tempo 5.2
# --> Chegada do cliente 70 no tempo 5.3
# --> Chegada do cliente 71 no tempo 5.3
# ▼ Servidor termina o atendimento do cliente 54 no tempo 5.3
# ▲ Servidor inicia o atendimento do cliente 55 no tempo 5.3
# ▼ Servidor termina o atendimento do cliente 55 no tempo 5.3
# ▲ Servidor inicia o atendimento do cliente 56 no tempo 5.3
# --> Chegada do cliente 72 no tempo 5.3
# --> Chegada do cliente 73 no tempo 5.4
# --> Chegada do cliente 74 no tempo 5.4
# ▼ Servidor termina o atendimento do cliente 56 no tempo 5.5
# ▲ Servidor inicia o atendimento do cliente 57 no tempo 5.5
# ▼ Servidor termina o atendimento do cliente 57 no tempo 5.5
# ▲ Servidor inicia o atendimento do cliente 58 no tempo 5.5
# --> Chegada do cliente 75 no tempo 5.6
# ▼ Servidor termina o atendimento do cliente 58 no tempo 5.6
# ▲ Servidor inicia o atendimento do cliente 59 no tempo 5.6
# ▼ Servidor termina o atendimento do cliente 59 no tempo 5.6
# ▲ Servidor inicia o atendimento do cliente 60 no tempo 5.6
# ▼ Servidor termina o atendimento do cliente 60 no tempo 5.6
# ▲ Servidor inicia o atendimento do cliente 61 no tempo 5.6
# --> Chegada do cliente 76 no tempo 5.6
# ▼ Servidor termina o atendimento do cliente 61 no tempo 5.8
# ▲ Servidor inicia o atendimento do cliente 62 no tempo 5.8
# ▼ Servidor termina o atendimento do cliente 62 no tempo 5.8
# ▲ Servidor inicia o atendimento do cliente 63 no tempo 5.8
# ▼ Servidor termina o atendimento do cliente 63 no tempo 5.9
# ▲ Servidor inicia o atendimento do cliente 64 no tempo 5.9
# ▼ Servidor termina o atendimento do cliente 64 no tempo 5.9
# ▲ Servidor inicia o atendimento do cliente 65 no tempo 5.9
# ▼ Servidor termina o atendimento do cliente 65 no tempo 5.9
# ▲ Servidor inicia o atendimento do cliente 66 no tempo 5.9
# ▼ Servidor termina o atendimento do cliente 66 no tempo 6.0
# ▲ Servidor inicia o atendimento do cliente 67 no tempo 6.0
# --> Chegada do cliente 77 no tempo 6.0
# --> Chegada do cliente 78 no tempo 6.0
# ▼ Servidor termina o atendimento do cliente 67 no tempo 6.1
# ▲ Servidor inicia o atendimento do cliente 68 no tempo 6.1
# --> Chegada do cliente 79 no tempo 6.1
# --> Chegada do cliente 80 no tempo 6.2
# --> Chegada do cliente 81 no tempo 6.2
# --> Chegada do cliente 82 no tempo 6.3
# --> Chegada do cliente 83 no tempo 6.3
# --> Chegada do cliente 84 no tempo 6.3
# --> Chegada do cliente 85 no tempo 6.3
# ▼ Servidor termina o atendimento do cliente 68 no tempo 6.3
# ▲ Servidor inicia o atendimento do cliente 69 no tempo 6.3
# --> Chegada do cliente 86 no tempo 6.4
# --> Chegada do cliente 87 no tempo 6.4
# ▼ Servidor termina o atendimento do cliente 69 no tempo 6.4
# ▲ Servidor inicia o atendimento do cliente 70 no tempo 6.4
# ▼ Servidor termina o atendimento do cliente 70 no tempo 6.5
# ▲ Servidor inicia o atendimento do cliente 71 no tempo 6.5
# --> Chegada do cliente 88 no tempo 6.6
# ▼ Servidor termina o atendimento do cliente 71 no tempo 6.6
# ▲ Servidor inicia o atendimento do cliente 72 no tempo 6.6
# ▼ Servidor termina o atendimento do cliente 72 no tempo 6.6
# ▲ Servidor inicia o atendimento do cliente 73 no tempo 6.6
# --> Chegada do cliente 89 no tempo 6.8
# ▼ Servidor termina o atendimento do cliente 73 no tempo 6.9
# ▲ Servidor inicia o atendimento do cliente 74 no tempo 6.9
# --> Chegada do cliente 90 no tempo 7.1
# --> Chegada do cliente 91 no tempo 7.1
# ▼ Servidor termina o atendimento do cliente 74 no tempo 7.1
# ▲ Servidor inicia o atendimento do cliente 75 no tempo 7.1
# --> Chegada do cliente 92 no tempo 7.3
# --> Chegada do cliente 93 no tempo 7.3
# --> Chegada do cliente 94 no tempo 7.5
# ▼ Servidor termina o atendimento do cliente 75 no tempo 7.5
# ▲ Servidor inicia o atendimento do cliente 76 no tempo 7.5
# ▼ Servidor termina o atendimento do cliente 76 no tempo 7.5
# ▲ Servidor inicia o atendimento do cliente 77 no tempo 7.5
# --> Chegada do cliente 95 no tempo 7.6
# ▼ Servidor termina o atendimento do cliente 77 no tempo 7.7
# ▲ Servidor inicia o atendimento do cliente 78 no tempo 7.7
# --> Chegada do cliente 96 no tempo 7.7
# --> Chegada do cliente 97 no tempo 7.8
# ▼ Servidor termina o atendimento do cliente 78 no tempo 7.8
# ▲ Servidor inicia o atendimento do cliente 79 no tempo 7.8
# ▼ Servidor termina o atendimento do cliente 79 no tempo 7.8
# ▲ Servidor inicia o atendimento do cliente 80 no tempo 7.8
# ▼ Servidor termina o atendimento do cliente 80 no tempo 7.8
# ▲ Servidor inicia o atendimento do cliente 81 no tempo 7.8
# --> Chegada do cliente 98 no tempo 8.1
# ▼ Servidor termina o atendimento do cliente 81 no tempo 8.1
# ▲ Servidor inicia o atendimento do cliente 82 no tempo 8.1
# --> Chegada do cliente 99 no tempo 8.1
# ▼ Servidor termina o atendimento do cliente 82 no tempo 8.1
# ▲ Servidor inicia o atendimento do cliente 83 no tempo 8.1
# --> Chegada do cliente 100 no tempo 8.2
# --> Chegada do cliente 101 no tempo 8.2
# ▼ Servidor termina o atendimento do cliente 83 no tempo 8.2
# ▲ Servidor inicia o atendimento do cliente 84 no tempo 8.2
# ▼ Servidor termina o atendimento do cliente 84 no tempo 8.3
# ▲ Servidor inicia o atendimento do cliente 85 no tempo 8.3
# ▼ Servidor termina o atendimento do cliente 85 no tempo 8.4
# ▲ Servidor inicia o atendimento do cliente 86 no tempo 8.4
# --> Chegada do cliente 102 no tempo 8.4
# --> Chegada do cliente 103 no tempo 8.4
# ▼ Servidor termina o atendimento do cliente 86 no tempo 8.4
# ▲ Servidor inicia o atendimento do cliente 87 no tempo 8.4
# ▼ Servidor termina o atendimento do cliente 87 no tempo 8.5
# ▲ Servidor inicia o atendimento do cliente 88 no tempo 8.5
# ▼ Servidor termina o atendimento do cliente 88 no tempo 8.7
# ▲ Servidor inicia o atendimento do cliente 89 no tempo 8.7
# --> Chegada do cliente 104 no tempo 8.8
# ▼ Servidor termina o atendimento do cliente 89 no tempo 8.8
# ▲ Servidor inicia o atendimento do cliente 90 no tempo 8.8
# ▼ Servidor termina o atendimento do cliente 90 no tempo 8.8
# ▲ Servidor inicia o atendimento do cliente 91 no tempo 8.8
# --> Chegada do cliente 105 no tempo 8.9
# --> Chegada do cliente 106 no tempo 8.9
# ▼ Servidor termina o atendimento do cliente 91 no tempo 8.9
# ▲ Servidor inicia o atendimento do cliente 92 no tempo 8.9
# --> Chegada do cliente 107 no tempo 8.9
# ▼ Servidor termina o atendimento do cliente 92 no tempo 9.0
# ▲ Servidor inicia o atendimento do cliente 93 no tempo 9.0
# ▼ Servidor termina o atendimento do cliente 93 no tempo 9.0
# ▲ Servidor inicia o atendimento do cliente 94 no tempo 9.0
# ▼ Servidor termina o atendimento do cliente 94 no tempo 9.1
# ▲ Servidor inicia o atendimento do cliente 95 no tempo 9.1
# --> Chegada do cliente 108 no tempo 9.2
# --> Chegada do cliente 109 no tempo 9.2
# ▼ Servidor termina o atendimento do cliente 95 no tempo 9.2
# ▲ Servidor inicia o atendimento do cliente 96 no tempo 9.2
# --> Chegada do cliente 110 no tempo 9.2
# --> Chegada do cliente 111 no tempo 9.3
# ▼ Servidor termina o atendimento do cliente 96 no tempo 9.3
# ▲ Servidor inicia o atendimento do cliente 97 no tempo 9.3
# ▼ Servidor termina o atendimento do cliente 97 no tempo 9.3
# ▲ Servidor inicia o atendimento do cliente 98 no tempo 9.3
# ▼ Servidor termina o atendimento do cliente 98 no tempo 9.5
# ▲ Servidor inicia o atendimento do cliente 99 no tempo 9.5
# ▼ Servidor termina o atendimento do cliente 99 no tempo 9.5
# ▲ Servidor inicia o atendimento do cliente 100 no tempo 9.5
# ▼ Servidor termina o atendimento do cliente 100 no tempo 9.6
# ▲ Servidor inicia o atendimento do cliente 101 no tempo 9.6
# ▼ Servidor termina o atendimento do cliente 101 no tempo 9.6
# ▲ Servidor inicia o atendimento do cliente 102 no tempo 9.6
# --> Chegada do cliente 112 no tempo 9.7
# --> Chegada do cliente 113 no tempo 9.7
# --> Chegada do cliente 114 no tempo 9.8
# --> Chegada do cliente 115 no tempo 9.8
# ▼ Servidor termina o atendimento do cliente 102 no tempo 9.8
# ▲ Servidor inicia o atendimento do cliente 103 no tempo 9.8
# --> Chegada do cliente 116 no tempo 9.8
# ▼ Servidor termina o atendimento do cliente 103 no tempo 9.9
# ▲ Servidor inicia o atendimento do cliente 104 no tempo 9.9
# --> Chegada do cliente 117 no tempo 10.0
# ▼ Servidor termina o atendimento do cliente 104 no tempo 10.0
# ▲ Servidor inicia o atendimento do cliente 105 no tempo 10.0
# --> Chegada do cliente 118 no tempo 10.0
# ▼ Servidor termina o atendimento do cliente 105 no tempo 10.2
# ▲ Servidor inicia o atendimento do cliente 106 no tempo 10.2
# --> Chegada do cliente 119 no tempo 10.2
# --> Chegada do cliente 120 no tempo 10.2
# ▼ Servidor termina o atendimento do cliente 106 no tempo 10.2
# ▲ Servidor inicia o atendimento do cliente 107 no tempo 10.2
# ▼ Servidor termina o atendimento do cliente 107 no tempo 10.3
# ▲ Servidor inicia o atendimento do cliente 108 no tempo 10.3
# ▼ Servidor termina o atendimento do cliente 108 no tempo 10.3
# ▲ Servidor inicia o atendimento do cliente 109 no tempo 10.3
# ▼ Servidor termina o atendimento do cliente 109 no tempo 10.3
# ▲ Servidor inicia o atendimento do cliente 110 no tempo 10.3
# ▼ Servidor termina o atendimento do cliente 110 no tempo 10.3
# ▲ Servidor inicia o atendimento do cliente 111 no tempo 10.3
# ▼ Servidor termina o atendimento do cliente 111 no tempo 10.3
# ▲ Servidor inicia o atendimento do cliente 112 no tempo 10.3
# ▼ Servidor termina o atendimento do cliente 112 no tempo 10.4
# ▲ Servidor inicia o atendimento do cliente 113 no tempo 10.4
# --> Chegada do cliente 121 no tempo 10.5
# ▼ Servidor termina o atendimento do cliente 113 no tempo 10.5
# ▲ Servidor inicia o atendimento do cliente 114 no tempo 10.5
# ▼ Servidor termina o atendimento do cliente 114 no tempo 10.5
# ▲ Servidor inicia o atendimento do cliente 115 no tempo 10.5
# ▼ Servidor termina o atendimento do cliente 115 no tempo 10.6
# ▲ Servidor inicia o atendimento do cliente 116 no tempo 10.6
# ▼ Servidor termina o atendimento do cliente 116 no tempo 10.6
# ▲ Servidor inicia o atendimento do cliente 117 no tempo 10.6
# --> Chegada do cliente 122 no tempo 10.6
# ▼ Servidor termina o atendimento do cliente 117 no tempo 10.6
# ▲ Servidor inicia o atendimento do cliente 118 no tempo 10.6
# ▼ Servidor termina o atendimento do cliente 118 no tempo 10.7
# ▲ Servidor inicia o atendimento do cliente 119 no tempo 10.7
# ▼ Servidor termina o atendimento do cliente 119 no tempo 10.7
# ▲ Servidor inicia o atendimento do cliente 120 no tempo 10.7
# ▼ Servidor termina o atendimento do cliente 120 no tempo 10.7
# ▲ Servidor inicia o atendimento do cliente 121 no tempo 10.7
# --> Chegada do cliente 123 no tempo 10.9
# ▼ Servidor termina o atendimento do cliente 121 no tempo 10.9
# ▲ Servidor inicia o atendimento do cliente 122 no tempo 10.9
# --> Chegada do cliente 124 no tempo 10.9
# ▼ Servidor termina o atendimento do cliente 122 no tempo 10.9
# ▲ Servidor inicia o atendimento do cliente 123 no tempo 10.9
# ▼ Servidor termina o atendimento do cliente 123 no tempo 11.0
# ▲ Servidor inicia o atendimento do cliente 124 no tempo 11.0
# --> Chegada do cliente 125 no tempo 11.0
# --> Chegada do cliente 126 no tempo 11.0
# --> Chegada do cliente 127 no tempo 11.0
# --> Chegada do cliente 128 no tempo 11.1
# --> Chegada do cliente 129 no tempo 11.1
# ▼ Servidor termina o atendimento do cliente 124 no tempo 11.2
# ▲ Servidor inicia o atendimento do cliente 125 no tempo 11.2
# ▼ Servidor termina o atendimento do cliente 125 no tempo 11.2
# ▲ Servidor inicia o atendimento do cliente 126 no tempo 11.2
# --> Chegada do cliente 130 no tempo 11.2
# ▼ Servidor termina o atendimento do cliente 126 no tempo 11.3
# ▲ Servidor inicia o atendimento do cliente 127 no tempo 11.3
# ▼ Servidor termina o atendimento do cliente 127 no tempo 11.3
# ▲ Servidor inicia o atendimento do cliente 128 no tempo 11.3
# --> Chegada do cliente 131 no tempo 11.3
# --> Chegada do cliente 132 no tempo 11.4
# ▼ Servidor termina o atendimento do cliente 128 no tempo 11.4
# ▲ Servidor inicia o atendimento do cliente 129 no tempo 11.4
# --> Chegada do cliente 133 no tempo 11.6
# ▼ Servidor termina o atendimento do cliente 129 no tempo 11.6
# ▲ Servidor inicia o atendimento do cliente 130 no tempo 11.6
# ▼ Servidor termina o atendimento do cliente 130 no tempo 11.7
# ▲ Servidor inicia o atendimento do cliente 131 no tempo 11.7
# ▼ Servidor termina o atendimento do cliente 131 no tempo 11.8
# ▲ Servidor inicia o atendimento do cliente 132 no tempo 11.8
# ▼ Servidor termina o atendimento do cliente 132 no tempo 11.8
# ▲ Servidor inicia o atendimento do cliente 133 no tempo 11.8
# ▼ Servidor termina o atendimento do cliente 133 no tempo 11.9
# --> Chegada do cliente 134 no tempo 12.0
# ▲ Servidor inicia o atendimento do cliente 134 no tempo 12.0
# --> Chegada do cliente 135 no tempo 12.0
# --> Chegada do cliente 136 no tempo 12.1
# --> Chegada do cliente 137 no tempo 12.3
# --> Chegada do cliente 138 no tempo 12.3
# --> Chegada do cliente 139 no tempo 12.3
# --> Chegada do cliente 140 no tempo 12.4
# ▼ Servidor termina o atendimento do cliente 134 no tempo 12.7
# ▲ Servidor inicia o atendimento do cliente 135 no tempo 12.7
# ▼ Servidor termina o atendimento do cliente 135 no tempo 12.7
# ▲ Servidor inicia o atendimento do cliente 136 no tempo 12.7
# --> Chegada do cliente 141 no tempo 12.7
# --> Chegada do cliente 142 no tempo 12.7
# ▼ Servidor termina o atendimento do cliente 136 no tempo 12.8
# ▲ Servidor inicia o atendimento do cliente 137 no tempo 12.8
# --> Chegada do cliente 143 no tempo 12.9
# ▼ Servidor termina o atendimento do cliente 137 no tempo 12.9
# ▲ Servidor inicia o atendimento do cliente 138 no tempo 12.9
# ▼ Servidor termina o atendimento do cliente 138 no tempo 12.9
# ▲ Servidor inicia o atendimento do cliente 139 no tempo 12.9
# ▼ Servidor termina o atendimento do cliente 139 no tempo 12.9
# ▲ Servidor inicia o atendimento do cliente 140 no tempo 12.9
# ▼ Servidor termina o atendimento do cliente 140 no tempo 13.2
# ▲ Servidor inicia o atendimento do cliente 141 no tempo 13.2
# ▼ Servidor termina o atendimento do cliente 141 no tempo 13.2
# ▲ Servidor inicia o atendimento do cliente 142 no tempo 13.2
# ▼ Servidor termina o atendimento do cliente 142 no tempo 13.3
# ▲ Servidor inicia o atendimento do cliente 143 no tempo 13.3
# --> Chegada do cliente 144 no tempo 13.3
# --> Chegada do cliente 145 no tempo 13.3
# ▼ Servidor termina o atendimento do cliente 143 no tempo 13.5
# ▲ Servidor inicia o atendimento do cliente 144 no tempo 13.5
# --> Chegada do cliente 146 no tempo 13.5
# --> Chegada do cliente 147 no tempo 13.5
# ▼ Servidor termina o atendimento do cliente 144 no tempo 13.5
# ▲ Servidor inicia o atendimento do cliente 145 no tempo 13.5
# --> Chegada do cliente 148 no tempo 13.5
# ▼ Servidor termina o atendimento do cliente 145 no tempo 13.7
# ▲ Servidor inicia o atendimento do cliente 146 no tempo 13.7
# ▼ Servidor termina o atendimento do cliente 146 no tempo 13.8
# ▲ Servidor inicia o atendimento do cliente 147 no tempo 13.8
# --> Chegada do cliente 149 no tempo 13.8
# --> Chegada do cliente 150 no tempo 13.9
# --> Chegada do cliente 151 no tempo 14.0
# --> Chegada do cliente 152 no tempo 14.1
# --> Chegada do cliente 153 no tempo 14.2
# --> Chegada do cliente 154 no tempo 14.2
# --> Chegada do cliente 155 no tempo 14.2
# --> Chegada do cliente 156 no tempo 14.3
# ▼ Servidor termina o atendimento do cliente 147 no tempo 14.3
# ▲ Servidor inicia o atendimento do cliente 148 no tempo 14.3
# ▼ Servidor termina o atendimento do cliente 148 no tempo 14.3
# ▲ Servidor inicia o atendimento do cliente 149 no tempo 14.3
# ▼ Servidor termina o atendimento do cliente 149 no tempo 14.4
# ▲ Servidor inicia o atendimento do cliente 150 no tempo 14.4
# --> Chegada do cliente 157 no tempo 14.5
# --> Chegada do cliente 158 no tempo 14.5
# ▼ Servidor termina o atendimento do cliente 150 no tempo 14.5
# ▲ Servidor inicia o atendimento do cliente 151 no tempo 14.5
# --> Chegada do cliente 159 no tempo 14.5
# ▼ Servidor termina o atendimento do cliente 151 no tempo 14.6
# ▲ Servidor inicia o atendimento do cliente 152 no tempo 14.6
# ▼ Servidor termina o atendimento do cliente 152 no tempo 14.6
# ▲ Servidor inicia o atendimento do cliente 153 no tempo 14.6
# --> Chegada do cliente 160 no tempo 14.6
# --> Chegada do cliente 161 no tempo 14.8
# --> Chegada do cliente 162 no tempo 14.8
# --> Chegada do cliente 163 no tempo 15.0
# --> Chegada do cliente 164 no tempo 15.1
# ▼ Servidor termina o atendimento do cliente 153 no tempo 15.1
# ▲ Servidor inicia o atendimento do cliente 154 no tempo 15.1
# ▼ Servidor termina o atendimento do cliente 154 no tempo 15.1
# ▲ Servidor inicia o atendimento do cliente 155 no tempo 15.1
# ▼ Servidor termina o atendimento do cliente 155 no tempo 15.3
# ▲ Servidor inicia o atendimento do cliente 156 no tempo 15.3
# --> Chegada do cliente 165 no tempo 15.3
# --> Chegada do cliente 166 no tempo 15.4
# ▼ Servidor termina o atendimento do cliente 156 no tempo 15.4
# ▲ Servidor inicia o atendimento do cliente 157 no tempo 15.4
# --> Chegada do cliente 167 no tempo 15.4
# ▼ Servidor termina o atendimento do cliente 157 no tempo 15.5
# ▲ Servidor inicia o atendimento do cliente 158 no tempo 15.5
# ▼ Servidor termina o atendimento do cliente 158 no tempo 15.6
# ▲ Servidor inicia o atendimento do cliente 159 no tempo 15.6
# ▼ Servidor termina o atendimento do cliente 159 no tempo 15.7
# ▲ Servidor inicia o atendimento do cliente 160 no tempo 15.7
# --> Chegada do cliente 168 no tempo 15.8
# ▼ Servidor termina o atendimento do cliente 160 no tempo 15.8
# ▲ Servidor inicia o atendimento do cliente 161 no tempo 15.8
# ▼ Servidor termina o atendimento do cliente 161 no tempo 15.9
# ▲ Servidor inicia o atendimento do cliente 162 no tempo 15.9
# --> Chegada do cliente 169 no tempo 15.9
# --> Chegada do cliente 170 no tempo 15.9
# ▼ Servidor termina o atendimento do cliente 162 no tempo 16.0
# ▲ Servidor inicia o atendimento do cliente 163 no tempo 16.0
# --> Chegada do cliente 171 no tempo 16.1
# --> Chegada do cliente 172 no tempo 16.2
# --> Chegada do cliente 173 no tempo 16.3
# ▼ Servidor termina o atendimento do cliente 163 no tempo 16.4
# ▲ Servidor inicia o atendimento do cliente 164 no tempo 16.4
# ▼ Servidor termina o atendimento do cliente 164 no tempo 16.4
# ▲ Servidor inicia o atendimento do cliente 165 no tempo 16.4
# --> Chegada do cliente 174 no tempo 16.5
# --> Chegada do cliente 175 no tempo 16.6
# --> Chegada do cliente 176 no tempo 16.7
# ▼ Servidor termina o atendimento do cliente 165 no tempo 16.7
# ▲ Servidor inicia o atendimento do cliente 166 no tempo 16.7
# --> Chegada do cliente 177 no tempo 16.9
# ▼ Servidor termina o atendimento do cliente 166 no tempo 16.9
# ▲ Servidor inicia o atendimento do cliente 167 no tempo 16.9
# --> Chegada do cliente 178 no tempo 17.0
# ▼ Servidor termina o atendimento do cliente 167 no tempo 17.0
# ▲ Servidor inicia o atendimento do cliente 168 no tempo 17.0
# --> Chegada do cliente 179 no tempo 17.0
# ▼ Servidor termina o atendimento do cliente 168 no tempo 17.1
# ▲ Servidor inicia o atendimento do cliente 169 no tempo 17.1
# --> Chegada do cliente 180 no tempo 17.1
# ▼ Servidor termina o atendimento do cliente 169 no tempo 17.1
# ▲ Servidor inicia o atendimento do cliente 170 no tempo 17.1
# --> Chegada do cliente 181 no tempo 17.1
# ▼ Servidor termina o atendimento do cliente 170 no tempo 17.1
# ▲ Servidor inicia o atendimento do cliente 171 no tempo 17.1
# ▼ Servidor termina o atendimento do cliente 171 no tempo 17.2
# ▲ Servidor inicia o atendimento do cliente 172 no tempo 17.2
# --> Chegada do cliente 182 no tempo 17.4
# ▼ Servidor termina o atendimento do cliente 172 no tempo 17.4
# ▲ Servidor inicia o atendimento do cliente 173 no tempo 17.4
# --> Chegada do cliente 183 no tempo 17.4
# --> Chegada do cliente 184 no tempo 17.5
# --> Chegada do cliente 185 no tempo 17.5
# --> Chegada do cliente 186 no tempo 17.6
# --> Chegada do cliente 187 no tempo 17.6
# --> Chegada do cliente 188 no tempo 17.7
# --> Chegada do cliente 189 no tempo 17.7
# --> Chegada do cliente 190 no tempo 17.7
# --> Chegada do cliente 191 no tempo 17.8
# --> Chegada do cliente 192 no tempo 17.8
# ▼ Servidor termina o atendimento do cliente 173 no tempo 17.9
# ▲ Servidor inicia o atendimento do cliente 174 no tempo 17.9
# --> Chegada do cliente 193 no tempo 18.0
# --> Chegada do cliente 194 no tempo 18.1
# ▼ Servidor termina o atendimento do cliente 174 no tempo 18.1
# ▲ Servidor inicia o atendimento do cliente 175 no tempo 18.1
# ▼ Servidor termina o atendimento do cliente 175 no tempo 18.1
# ▲ Servidor inicia o atendimento do cliente 176 no tempo 18.1
# ▼ Servidor termina o atendimento do cliente 176 no tempo 18.2
# ▲ Servidor inicia o atendimento do cliente 177 no tempo 18.2
# --> Chegada do cliente 195 no tempo 18.2
# ▼ Servidor termina o atendimento do cliente 177 no tempo 18.3
# ▲ Servidor inicia o atendimento do cliente 178 no tempo 18.3
# --> Chegada do cliente 196 no tempo 18.4
# --> Chegada do cliente 197 no tempo 18.5
# --> Chegada do cliente 198 no tempo 18.7
# ▼ Servidor termina o atendimento do cliente 178 no tempo 18.7
# ▲ Servidor inicia o atendimento do cliente 179 no tempo 18.7
# ▼ Servidor termina o atendimento do cliente 179 no tempo 18.7
# ▲ Servidor inicia o atendimento do cliente 180 no tempo 18.7
# ▼ Servidor termina o atendimento do cliente 180 no tempo 18.7
# ▲ Servidor inicia o atendimento do cliente 181 no tempo 18.7
# ▼ Servidor termina o atendimento do cliente 181 no tempo 18.7
# ▲ Servidor inicia o atendimento do cliente 182 no tempo 18.7
# --> Chegada do cliente 199 no tempo 18.8
# --> Chegada do cliente 200 no tempo 18.8
# ▼ Servidor termina o atendimento do cliente 182 no tempo 18.8
# ▲ Servidor inicia o atendimento do cliente 183 no tempo 18.8
# --> Chegada do cliente 201 no tempo 18.9
# ▼ Servidor termina o atendimento do cliente 183 no tempo 18.9
# ▲ Servidor inicia o atendimento do cliente 184 no tempo 18.9
# ▼ Servidor termina o atendimento do cliente 184 no tempo 19.0
# ▲ Servidor inicia o atendimento do cliente 185 no tempo 19.0
# --> Chegada do cliente 202 no tempo 19.1
# --> Chegada do cliente 203 no tempo 19.2
# ▼ Servidor termina o atendimento do cliente 185 no tempo 19.2
# ▲ Servidor inicia o atendimento do cliente 186 no tempo 19.2
# --> Chegada do cliente 204 no tempo 19.3
# --> Chegada do cliente 205 no tempo 19.3
# ▼ Servidor termina o atendimento do cliente 186 no tempo 19.3
# ▲ Servidor inicia o atendimento do cliente 187 no tempo 19.3
# ▼ Servidor termina o atendimento do cliente 187 no tempo 19.3
# ▲ Servidor inicia o atendimento do cliente 188 no tempo 19.3
# ▼ Servidor termina o atendimento do cliente 188 no tempo 19.4
# ▲ Servidor inicia o atendimento do cliente 189 no tempo 19.4
# --> Chegada do cliente 206 no tempo 19.5
# --> Chegada do cliente 207 no tempo 19.5
# --> Chegada do cliente 208 no tempo 19.6
# ▼ Servidor termina o atendimento do cliente 189 no tempo 19.7
# ▲ Servidor inicia o atendimento do cliente 190 no tempo 19.7
# ▼ Servidor termina o atendimento do cliente 190 no tempo 19.7
# ▲ Servidor inicia o atendimento do cliente 191 no tempo 19.7
# --> Chegada do cliente 209 no tempo 19.8
# ▼ Servidor termina o atendimento do cliente 191 no tempo 19.8
# ▲ Servidor inicia o atendimento do cliente 192 no tempo 19.8
# ▼ Servidor termina o atendimento do cliente 192 no tempo 19.8
# ▲ Servidor inicia o atendimento do cliente 193 no tempo 19.8
# ▼ Servidor termina o atendimento do cliente 193 no tempo 19.8
# ▲ Servidor inicia o atendimento do cliente 194 no tempo 19.8
# --> Chegada do cliente 210 no tempo 19.9
# --> Chegada do cliente 211 no tempo 20.1
# --> Chegada do cliente 212 no tempo 20.2
# ▼ Servidor termina o atendimento do cliente 194 no tempo 20.2
# ▲ Servidor inicia o atendimento do cliente 195 no tempo 20.2
# --> Chegada do cliente 213 no tempo 20.3
# ▼ Servidor termina o atendimento do cliente 195 no tempo 20.3
# ▲ Servidor inicia o atendimento do cliente 196 no tempo 20.3
# ▼ Servidor termina o atendimento do cliente 196 no tempo 20.3
# ▲ Servidor inicia o atendimento do cliente 197 no tempo 20.3
# ▼ Servidor termina o atendimento do cliente 197 no tempo 20.4
# ▲ Servidor inicia o atendimento do cliente 198 no tempo 20.4
# ▼ Servidor termina o atendimento do cliente 198 no tempo 20.4
# ▲ Servidor inicia o atendimento do cliente 199 no tempo 20.4
# ▼ Servidor termina o atendimento do cliente 199 no tempo 20.5
# ▲ Servidor inicia o atendimento do cliente 200 no tempo 20.5
# --> Chegada do cliente 214 no tempo 20.5
# --> Chegada do cliente 215 no tempo 20.5
# --> Chegada do cliente 216 no tempo 20.5
# --> Chegada do cliente 217 no tempo 20.6
# --> Chegada do cliente 218 no tempo 20.7
# ▼ Servidor termina o atendimento do cliente 200 no tempo 20.8
# ▲ Servidor inicia o atendimento do cliente 201 no tempo 20.8
# ▼ Servidor termina o atendimento do cliente 201 no tempo 20.8
# ▲ Servidor inicia o atendimento do cliente 202 no tempo 20.8
# --> Chegada do cliente 219 no tempo 20.8
# --> Chegada do cliente 220 no tempo 20.9
# --> Chegada do cliente 221 no tempo 20.9
# --> Chegada do cliente 222 no tempo 20.9
# ▼ Servidor termina o atendimento do cliente 202 no tempo 20.9
# ▲ Servidor inicia o atendimento do cliente 203 no tempo 20.9
# --> Chegada do cliente 223 no tempo 21.1
# --> Chegada do cliente 224 no tempo 21.1
# ▼ Servidor termina o atendimento do cliente 203 no tempo 21.2
# ▲ Servidor inicia o atendimento do cliente 204 no tempo 21.2
# --> Chegada do cliente 225 no tempo 21.3
# --> Chegada do cliente 226 no tempo 21.3
# --> Chegada do cliente 227 no tempo 21.3
# --> Chegada do cliente 228 no tempo 21.3
# --> Chegada do cliente 229 no tempo 21.4
# --> Chegada do cliente 230 no tempo 21.4
# ▼ Servidor termina o atendimento do cliente 204 no tempo 21.5
# ▲ Servidor inicia o atendimento do cliente 205 no tempo 21.5
# ▼ Servidor termina o atendimento do cliente 205 no tempo 21.5
# ▲ Servidor inicia o atendimento do cliente 206 no tempo 21.5
# ▼ Servidor termina o atendimento do cliente 206 no tempo 21.5
# ▲ Servidor inicia o atendimento do cliente 207 no tempo 21.5
# ▼ Servidor termina o atendimento do cliente 207 no tempo 21.6
# ▲ Servidor inicia o atendimento do cliente 208 no tempo 21.6
# ▼ Servidor termina o atendimento do cliente 208 no tempo 21.7
# ▲ Servidor inicia o atendimento do cliente 209 no tempo 21.7
# ▼ Servidor termina o atendimento do cliente 209 no tempo 21.8
# ▲ Servidor inicia o atendimento do cliente 210 no tempo 21.8
# --> Chegada do cliente 231 no tempo 21.8
# ▼ Servidor termina o atendimento do cliente 210 no tempo 21.8
# ▲ Servidor inicia o atendimento do cliente 211 no tempo 21.8
# --> Chegada do cliente 232 no tempo 21.9
# --> Chegada do cliente 233 no tempo 22.0
# ▼ Servidor termina o atendimento do cliente 211 no tempo 22.0
# ▲ Servidor inicia o atendimento do cliente 212 no tempo 22.0
# --> Chegada do cliente 234 no tempo 22.0
# --> Chegada do cliente 235 no tempo 22.0
# ▼ Servidor termina o atendimento do cliente 212 no tempo 22.1
# ▲ Servidor inicia o atendimento do cliente 213 no tempo 22.1
# --> Chegada do cliente 236 no tempo 22.1
# ▼ Servidor termina o atendimento do cliente 213 no tempo 22.2
# ▲ Servidor inicia o atendimento do cliente 214 no tempo 22.2
# --> Chegada do cliente 237 no tempo 22.4
# --> Chegada do cliente 238 no tempo 22.4
# --> Chegada do cliente 239 no tempo 22.5
# --> Chegada do cliente 240 no tempo 22.6
# --> Chegada do cliente 241 no tempo 22.6
# --> Chegada do cliente 242 no tempo 22.7
# ▼ Servidor termina o atendimento do cliente 214 no tempo 22.7
# ▲ Servidor inicia o atendimento do cliente 215 no tempo 22.7
# --> Chegada do cliente 243 no tempo 22.7
# --> Chegada do cliente 244 no tempo 22.7
# ▼ Servidor termina o atendimento do cliente 215 no tempo 22.7
# ▲ Servidor inicia o atendimento do cliente 216 no tempo 22.7
# --> Chegada do cliente 245 no tempo 22.8
# --> Chegada do cliente 246 no tempo 22.9
# --> Chegada do cliente 247 no tempo 22.9
# --> Chegada do cliente 248 no tempo 22.9
# --> Chegada do cliente 249 no tempo 23.0
# ▼ Servidor termina o atendimento do cliente 216 no tempo 23.0
# ▲ Servidor inicia o atendimento do cliente 217 no tempo 23.0
# ▼ Servidor termina o atendimento do cliente 217 no tempo 23.0
# ▲ Servidor inicia o atendimento do cliente 218 no tempo 23.0
# ▼ Servidor termina o atendimento do cliente 218 no tempo 23.0
# ▲ Servidor inicia o atendimento do cliente 219 no tempo 23.0
# --> Chegada do cliente 250 no tempo 23.1
# --> Chegada do cliente 251 no tempo 23.2
# ▼ Servidor termina o atendimento do cliente 219 no tempo 23.2
# ▲ Servidor inicia o atendimento do cliente 220 no tempo 23.2
# --> Chegada do cliente 252 no tempo 23.2
# --> Chegada do cliente 253 no tempo 23.2
# ▼ Servidor termina o atendimento do cliente 220 no tempo 23.3
# ▲ Servidor inicia o atendimento do cliente 221 no tempo 23.3
# --> Chegada do cliente 254 no tempo 23.3
# --> Chegada do cliente 255 no tempo 23.3
# --> Chegada do cliente 256 no tempo 23.4
# ▼ Servidor termina o atendimento do cliente 221 no tempo 23.5
# ▲ Servidor inicia o atendimento do cliente 222 no tempo 23.5
# ▼ Servidor termina o atendimento do cliente 222 no tempo 23.5
# ▲ Servidor inicia o atendimento do cliente 223 no tempo 23.5
# ▼ Servidor termina o atendimento do cliente 223 no tempo 23.5
# ▲ Servidor inicia o atendimento do cliente 224 no tempo 23.5
# --> Chegada do cliente 257 no tempo 23.6
# --> Chegada do cliente 258 no tempo 23.6
# --> Chegada do cliente 259 no tempo 23.6
# --> Chegada do cliente 260 no tempo 23.7
# ▼ Servidor termina o atendimento do cliente 224 no tempo 23.8
# ▲ Servidor inicia o atendimento do cliente 225 no tempo 23.8
# ▼ Servidor termina o atendimento do cliente 225 no tempo 23.8
# ▲ Servidor inicia o atendimento do cliente 226 no tempo 23.8
# --> Chegada do cliente 261 no tempo 23.8
# --> Chegada do cliente 262 no tempo 23.9
# ▼ Servidor termina o atendimento do cliente 226 no tempo 24.0
# ▲ Servidor inicia o atendimento do cliente 227 no tempo 24.0
# ▼ Servidor termina o atendimento do cliente 227 no tempo 24.0
# ▲ Servidor inicia o atendimento do cliente 228 no tempo 24.0
# ▼ Servidor termina o atendimento do cliente 228 no tempo 24.1
# ▲ Servidor inicia o atendimento do cliente 229 no tempo 24.1
# ▼ Servidor termina o atendimento do cliente 229 no tempo 24.1
# ▲ Servidor inicia o atendimento do cliente 230 no tempo 24.1
# ▼ Servidor termina o atendimento do cliente 230 no tempo 24.1
# ▲ Servidor inicia o atendimento do cliente 231 no tempo 24.1
# --> Chegada do cliente 263 no tempo 24.2
# --> Chegada do cliente 264 no tempo 24.2
# ▼ Servidor termina o atendimento do cliente 231 no tempo 24.2
# ▲ Servidor inicia o atendimento do cliente 232 no tempo 24.2
# ▼ Servidor termina o atendimento do cliente 232 no tempo 24.3
# ▲ Servidor inicia o atendimento do cliente 233 no tempo 24.3
# --> Chegada do cliente 265 no tempo 24.3
# --> Chegada do cliente 266 no tempo 24.3
# ▼ Servidor termina o atendimento do cliente 233 no tempo 24.4
# ▲ Servidor inicia o atendimento do cliente 234 no tempo 24.4
# --> Chegada do cliente 267 no tempo 24.4
# --> Chegada do cliente 268 no tempo 24.4
# ▼ Servidor termina o atendimento do cliente 234 no tempo 24.5
# ▲ Servidor inicia o atendimento do cliente 235 no tempo 24.5
# --> Chegada do cliente 269 no tempo 24.6
# ▼ Servidor termina o atendimento do cliente 235 no tempo 24.6
# ▲ Servidor inicia o atendimento do cliente 236 no tempo 24.6
# --> Chegada do cliente 270 no tempo 24.6
# ▼ Servidor termina o atendimento do cliente 236 no tempo 24.7
# ▲ Servidor inicia o atendimento do cliente 237 no tempo 24.7
# --> Chegada do cliente 271 no tempo 24.7
# --> Chegada do cliente 272 no tempo 24.7
# --> Chegada do cliente 273 no tempo 24.7
# --> Chegada do cliente 274 no tempo 24.8
# --> Chegada do cliente 275 no tempo 24.8
# ▼ Servidor termina o atendimento do cliente 237 no tempo 24.8
# ▲ Servidor inicia o atendimento do cliente 238 no tempo 24.8
# --> Chegada do cliente 276 no tempo 25.0
# --> Chegada do cliente 277 no tempo 25.0
# --> Chegada do cliente 278 no tempo 25.0
# ▼ Servidor termina o atendimento do cliente 238 no tempo 25.0
# ▲ Servidor inicia o atendimento do cliente 239 no tempo 25.0
# ▼ Servidor termina o atendimento do cliente 239 no tempo 25.1
# ▲ Servidor inicia o atendimento do cliente 240 no tempo 25.1
# ▼ Servidor termina o atendimento do cliente 240 no tempo 25.1
# ▲ Servidor inicia o atendimento do cliente 241 no tempo 25.1
# ▼ Servidor termina o atendimento do cliente 241 no tempo 25.1
# ▲ Servidor inicia o atendimento do cliente 242 no tempo 25.1
# --> Chegada do cliente 279 no tempo 25.2
# --> Chegada do cliente 280 no tempo 25.2
# --> Chegada do cliente 281 no tempo 25.3
# --> Chegada do cliente 282 no tempo 25.4
# --> Chegada do cliente 283 no tempo 25.6
# ▼ Servidor termina o atendimento do cliente 242 no tempo 25.6
# ▲ Servidor inicia o atendimento do cliente 243 no tempo 25.6
# ▼ Servidor termina o atendimento do cliente 243 no tempo 25.6
# ▲ Servidor inicia o atendimento do cliente 244 no tempo 25.6
# ▼ Servidor termina o atendimento do cliente 244 no tempo 25.6
# ▲ Servidor inicia o atendimento do cliente 245 no tempo 25.6
# ▼ Servidor termina o atendimento do cliente 245 no tempo 25.7
# ▲ Servidor inicia o atendimento do cliente 246 no tempo 25.7
# --> Chegada do cliente 284 no tempo 25.7
# --> Chegada do cliente 285 no tempo 25.7
# ▼ Servidor termina o atendimento do cliente 246 no tempo 25.7
# ▲ Servidor inicia o atendimento do cliente 247 no tempo 25.7
# ▼ Servidor termina o atendimento do cliente 247 no tempo 25.7
# ▲ Servidor inicia o atendimento do cliente 248 no tempo 25.7
# --> Chegada do cliente 286 no tempo 25.8
# ▼ Servidor termina o atendimento do cliente 248 no tempo 25.8
# ▲ Servidor inicia o atendimento do cliente 249 no tempo 25.8
# ▼ Servidor termina o atendimento do cliente 249 no tempo 25.8
# ▲ Servidor inicia o atendimento do cliente 250 no tempo 25.8
# ▼ Servidor termina o atendimento do cliente 250 no tempo 25.9
# ▲ Servidor inicia o atendimento do cliente 251 no tempo 25.9
# --> Chegada do cliente 287 no tempo 25.9
# --> Chegada do cliente 288 no tempo 26.0
# ▼ Servidor termina o atendimento do cliente 251 no tempo 26.0
# ▲ Servidor inicia o atendimento do cliente 252 no tempo 26.0
# ▼ Servidor termina o atendimento do cliente 252 no tempo 26.1
# ▲ Servidor inicia o atendimento do cliente 253 no tempo 26.1
# ▼ Servidor termina o atendimento do cliente 253 no tempo 26.1
# ▲ Servidor inicia o atendimento do cliente 254 no tempo 26.1
# ▼ Servidor termina o atendimento do cliente 254 no tempo 26.1
# ▲ Servidor inicia o atendimento do cliente 255 no tempo 26.1
# --> Chegada do cliente 289 no tempo 26.2
# ▼ Servidor termina o atendimento do cliente 255 no tempo 26.2
# ▲ Servidor inicia o atendimento do cliente 256 no tempo 26.2
# --> Chegada do cliente 290 no tempo 26.3
# --> Chegada do cliente 291 no tempo 26.4
# --> Chegada do cliente 292 no tempo 26.4
# --> Chegada do cliente 293 no tempo 26.4
# --> Chegada do cliente 294 no tempo 26.4
# ▼ Servidor termina o atendimento do cliente 256 no tempo 26.4
# ▲ Servidor inicia o atendimento do cliente 257 no tempo 26.4
# ▼ Servidor termina o atendimento do cliente 257 no tempo 26.4
# ▲ Servidor inicia o atendimento do cliente 258 no tempo 26.4
# --> Chegada do cliente 295 no tempo 26.7
# --> Chegada do cliente 296 no tempo 26.7
# --> Chegada do cliente 297 no tempo 26.7
# --> Chegada do cliente 298 no tempo 26.7
# --> Chegada do cliente 299 no tempo 26.7
# --> Chegada do cliente 300 no tempo 26.8
# ▼ Servidor termina o atendimento do cliente 258 no tempo 26.8
# ▲ Servidor inicia o atendimento do cliente 259 no tempo 26.8
# --> Chegada do cliente 301 no tempo 27.1
# ▼ Servidor termina o atendimento do cliente 259 no tempo 27.2
# ▲ Servidor inicia o atendimento do cliente 260 no tempo 27.2
# --> Chegada do cliente 302 no tempo 27.3
# ▼ Servidor termina o atendimento do cliente 260 no tempo 27.3
# ▲ Servidor inicia o atendimento do cliente 261 no tempo 27.3
# --> Chegada do cliente 303 no tempo 27.3
# ▼ Servidor termina o atendimento do cliente 261 no tempo 27.3
# ▲ Servidor inicia o atendimento do cliente 262 no tempo 27.3
# --> Chegada do cliente 304 no tempo 27.4
# ▼ Servidor termina o atendimento do cliente 262 no tempo 27.4
# ▲ Servidor inicia o atendimento do cliente 263 no tempo 27.4
# ▼ Servidor termina o atendimento do cliente 263 no tempo 27.4
# ▲ Servidor inicia o atendimento do cliente 264 no tempo 27.4
# --> Chegada do cliente 305 no tempo 27.5
# ▼ Servidor termina o atendimento do cliente 264 no tempo 27.5
# ▲ Servidor inicia o atendimento do cliente 265 no tempo 27.5
# ▼ Servidor termina o atendimento do cliente 265 no tempo 27.5
# ▲ Servidor inicia o atendimento do cliente 266 no tempo 27.5
# ▼ Servidor termina o atendimento do cliente 266 no tempo 27.5
# ▲ Servidor inicia o atendimento do cliente 267 no tempo 27.5
# --> Chegada do cliente 306 no tempo 27.5
# --> Chegada do cliente 307 no tempo 27.6
# ▼ Servidor termina o atendimento do cliente 267 no tempo 27.6
# ▲ Servidor inicia o atendimento do cliente 268 no tempo 27.6
# --> Chegada do cliente 308 no tempo 27.6
# --> Chegada do cliente 309 no tempo 27.6
# --> Chegada do cliente 310 no tempo 27.7
# --> Chegada do cliente 311 no tempo 27.7
# ▼ Servidor termina o atendimento do cliente 268 no tempo 27.8
# ▲ Servidor inicia o atendimento do cliente 269 no tempo 27.8
# --> Chegada do cliente 312 no tempo 28.0
# --> Chegada do cliente 313 no tempo 28.1
# --> Chegada do cliente 314 no tempo 28.1
# --> Chegada do cliente 315 no tempo 28.2
# ▼ Servidor termina o atendimento do cliente 269 no tempo 28.3
# ▲ Servidor inicia o atendimento do cliente 270 no tempo 28.3
# ▼ Servidor termina o atendimento do cliente 270 no tempo 28.3
# ▲ Servidor inicia o atendimento do cliente 271 no tempo 28.3
# ▼ Servidor termina o atendimento do cliente 271 no tempo 28.4
# ▲ Servidor inicia o atendimento do cliente 272 no tempo 28.4
# --> Chegada do cliente 316 no tempo 28.4
# --> Chegada do cliente 317 no tempo 28.5
# ▼ Servidor termina o atendimento do cliente 272 no tempo 28.6
# ▲ Servidor inicia o atendimento do cliente 273 no tempo 28.6
# ▼ Servidor termina o atendimento do cliente 273 no tempo 28.6
# ▲ Servidor inicia o atendimento do cliente 274 no tempo 28.6
# --> Chegada do cliente 318 no tempo 28.8
# --> Chegada do cliente 319 no tempo 28.8
# ▼ Servidor termina o atendimento do cliente 274 no tempo 28.9
# ▲ Servidor inicia o atendimento do cliente 275 no tempo 28.9
# --> Chegada do cliente 320 no tempo 29.0
# ▼ Servidor termina o atendimento do cliente 275 no tempo 29.0
# ▲ Servidor inicia o atendimento do cliente 276 no tempo 29.0
# --> Chegada do cliente 321 no tempo 29.1
# --> Chegada do cliente 322 no tempo 29.1
# ▼ Servidor termina o atendimento do cliente 276 no tempo 29.1
# ▲ Servidor inicia o atendimento do cliente 277 no tempo 29.1
# --> Chegada do cliente 323 no tempo 29.1
# --> Chegada do cliente 324 no tempo 29.2
# --> Chegada do cliente 325 no tempo 29.2
# --> Chegada do cliente 326 no tempo 29.3
# ▼ Servidor termina o atendimento do cliente 277 no tempo 29.3
# ▲ Servidor inicia o atendimento do cliente 278 no tempo 29.3
# --> Chegada do cliente 327 no tempo 29.3
# ▼ Servidor termina o atendimento do cliente 278 no tempo 29.5
# ▲ Servidor inicia o atendimento do cliente 279 no tempo 29.5
# --> Chegada do cliente 328 no tempo 29.5
# --> Chegada do cliente 329 no tempo 29.6
# --> Chegada do cliente 330 no tempo 29.6
# --> Chegada do cliente 331 no tempo 29.7
# ▼ Servidor termina o atendimento do cliente 279 no tempo 29.7
# ▲ Servidor inicia o atendimento do cliente 280 no tempo 29.7
# --> Chegada do cliente 332 no tempo 29.7
# ▼ Servidor termina o atendimento do cliente 280 no tempo 29.9
# ▲ Servidor inicia o atendimento do cliente 281 no tempo 29.9
# ▼ Servidor termina o atendimento do cliente 281 no tempo 29.9
# ▲ Servidor inicia o atendimento do cliente 282 no tempo 29.9
# --> Chegada do cliente 333 no tempo 30.0
# --> Chegada do cliente 334 no tempo 30.1
# --> Chegada do cliente 335 no tempo 30.1
# --> Chegada do cliente 336 no tempo 30.1
# ▼ Servidor termina o atendimento do cliente 282 no tempo 30.1
# ▲ Servidor inicia o atendimento do cliente 283 no tempo 30.1
# --> Chegada do cliente 337 no tempo 30.2
# ▼ Servidor termina o atendimento do cliente 283 no tempo 30.2
# ...
# --> Chegada do cliente 1000 no tempo 91.2
# ▼ Servidor termina o atendimento do cliente 872 no tempo 91.2
# ▲ Servidor inicia o atendimento do cliente 873 no tempo 91.2
# ▼ Servidor termina o atendimento do cliente 873 no tempo 91.3
# ▲ Servidor inicia o atendimento do cliente 874 no tempo 91.3
# ▼ Servidor termina o atendimento do cliente 874 no tempo 91.4
# ▲ Servidor inicia o atendimento do cliente 875 no tempo 91.4
# ▼ Servidor termina o atendimento do cliente 875 no tempo 91.4
# ▲ Servidor inicia o atendimento do cliente 876 no tempo 91.4
# ▼ Servidor termina o atendimento do cliente 876 no tempo 91.8
# ▲ Servidor inicia o atendimento do cliente 877 no tempo 91.8
# ▼ Servidor termina o atendimento do cliente 877 no tempo 92.1
# ▲ Servidor inicia o atendimento do cliente 878 no tempo 92.1
# ▼ Servidor termina o atendimento do cliente 878 no tempo 92.2
# ▲ Servidor inicia o atendimento do cliente 879 no tempo 92.2
# ▼ Servidor termina o atendimento do cliente 879 no tempo 92.3
# ▲ Servidor inicia o atendimento do cliente 880 no tempo 92.3
# ▼ Servidor termina o atendimento do cliente 880 no tempo 92.4
# ▲ Servidor inicia o atendimento do cliente 881 no tempo 92.4
# ▼ Servidor termina o atendimento do cliente 881 no tempo 92.4
# ▲ Servidor inicia o atendimento do cliente 882 no tempo 92.4
# ▼ Servidor termina o atendimento do cliente 882 no tempo 92.5
# ▲ Servidor inicia o atendimento do cliente 883 no tempo 92.5
# ▼ Servidor termina o atendimento do cliente 883 no tempo 92.5
# ▲ Servidor inicia o atendimento do cliente 884 no tempo 92.5
# ▼ Servidor termina o atendimento do cliente 884 no tempo 92.5
# ▲ Servidor inicia o atendimento do cliente 885 no tempo 92.5
# ▼ Servidor termina o atendimento do cliente 885 no tempo 92.6
# ▲ Servidor inicia o atendimento do cliente 886 no tempo 92.6
# ▼ Servidor termina o atendimento do cliente 886 no tempo 92.7
# ▲ Servidor inicia o atendimento do cliente 887 no tempo 92.7
# ▼ Servidor termina o atendimento do cliente 887 no tempo 93.0
# ▲ Servidor inicia o atendimento do cliente 888 no tempo 93.0
# ▼ Servidor termina o atendimento do cliente 888 no tempo 93.2
# ▲ Servidor inicia o atendimento do cliente 889 no tempo 93.2
# ▼ Servidor termina o atendimento do cliente 889 no tempo 93.3
# ▲ Servidor inicia o atendimento do cliente 890 no tempo 93.3
# ▼ Servidor termina o atendimento do cliente 890 no tempo 93.5
# ▲ Servidor inicia o atendimento do cliente 891 no tempo 93.5
# ▼ Servidor termina o atendimento do cliente 891 no tempo 93.6
# ▲ Servidor inicia o atendimento do cliente 892 no tempo 93.6
# ▼ Servidor termina o atendimento do cliente 892 no tempo 93.8
# ▲ Servidor inicia o atendimento do cliente 893 no tempo 93.8
# ▼ Servidor termina o atendimento do cliente 893 no tempo 93.8
# ▲ Servidor inicia o atendimento do cliente 894 no tempo 93.8
# ▼ Servidor termina o atendimento do cliente 894 no tempo 94.1
# ▲ Servidor inicia o atendimento do cliente 895 no tempo 94.1
# ▼ Servidor termina o atendimento do cliente 895 no tempo 94.2
# ▲ Servidor inicia o atendimento do cliente 896 no tempo 94.2
# ▼ Servidor termina o atendimento do cliente 896 no tempo 94.2
# ▲ Servidor inicia o atendimento do cliente 897 no tempo 94.2
# ▼ Servidor termina o atendimento do cliente 897 no tempo 94.3
# ▲ Servidor inicia o atendimento do cliente 898 no tempo 94.3
# ▼ Servidor termina o atendimento do cliente 898 no tempo 94.4
# ▲ Servidor inicia o atendimento do cliente 899 no tempo 94.4
# ▼ Servidor termina o atendimento do cliente 899 no tempo 94.4
# ▲ Servidor inicia o atendimento do cliente 900 no tempo 94.4
# ▼ Servidor termina o atendimento do cliente 900 no tempo 94.5
# ▲ Servidor inicia o atendimento do cliente 901 no tempo 94.5
# ▼ Servidor termina o atendimento do cliente 901 no tempo 94.7
# ▲ Servidor inicia o atendimento do cliente 902 no tempo 94.7
# ▼ Servidor termina o atendimento do cliente 902 no tempo 94.7
# ▲ Servidor inicia o atendimento do cliente 903 no tempo 94.7
# ▼ Servidor termina o atendimento do cliente 903 no tempo 94.7
# ▲ Servidor inicia o atendimento do cliente 904 no tempo 94.7
# ▼ Servidor termina o atendimento do cliente 904 no tempo 94.8
# ▲ Servidor inicia o atendimento do cliente 905 no tempo 94.8
# ▼ Servidor termina o atendimento do cliente 905 no tempo 94.8
# ▲ Servidor inicia o atendimento do cliente 906 no tempo 94.8
# ▼ Servidor termina o atendimento do cliente 906 no tempo 94.8
# ▲ Servidor inicia o atendimento do cliente 907 no tempo 94.8
# ▼ Servidor termina o atendimento do cliente 907 no tempo 95.0
# ▲ Servidor inicia o atendimento do cliente 908 no tempo 95.0
# ▼ Servidor termina o atendimento do cliente 908 no tempo 95.0
# ▲ Servidor inicia o atendimento do cliente 909 no tempo 95.0
# ▼ Servidor termina o atendimento do cliente 909 no tempo 95.1
# ▲ Servidor inicia o atendimento do cliente 910 no tempo 95.1
# ▼ Servidor termina o atendimento do cliente 910 no tempo 95.1
# ▲ Servidor inicia o atendimento do cliente 911 no tempo 95.1
# ▼ Servidor termina o atendimento do cliente 911 no tempo 95.2
# ▲ Servidor inicia o atendimento do cliente 912 no tempo 95.2
# ▼ Servidor termina o atendimento do cliente 912 no tempo 95.4
# ▲ Servidor inicia o atendimento do cliente 913 no tempo 95.4
# ▼ Servidor termina o atendimento do cliente 913 no tempo 95.5
# ▲ Servidor inicia o atendimento do cliente 914 no tempo 95.5
# ▼ Servidor termina o atendimento do cliente 914 no tempo 95.7
# ▲ Servidor inicia o atendimento do cliente 915 no tempo 95.7
# ▼ Servidor termina o atendimento do cliente 915 no tempo 95.8
# ▲ Servidor inicia o atendimento do cliente 916 no tempo 95.8
# ▼ Servidor termina o atendimento do cliente 916 no tempo 96.0
# ▲ Servidor inicia o atendimento do cliente 917 no tempo 96.0
# ▼ Servidor termina o atendimento do cliente 917 no tempo 96.1
# ▲ Servidor inicia o atendimento do cliente 918 no tempo 96.1
# ▼ Servidor termina o atendimento do cliente 918 no tempo 96.1
# ▲ Servidor inicia o atendimento do cliente 919 no tempo 96.1
# ▼ Servidor termina o atendimento do cliente 919 no tempo 96.1
# ▲ Servidor inicia o atendimento do cliente 920 no tempo 96.1
# ▼ Servidor termina o atendimento do cliente 920 no tempo 96.5
# ▲ Servidor inicia o atendimento do cliente 921 no tempo 96.5
# ▼ Servidor termina o atendimento do cliente 921 no tempo 96.7
# ▲ Servidor inicia o atendimento do cliente 922 no tempo 96.7
# ▼ Servidor termina o atendimento do cliente 922 no tempo 96.7
# ▲ Servidor inicia o atendimento do cliente 923 no tempo 96.7
# ▼ Servidor termina o atendimento do cliente 923 no tempo 96.8
# ▲ Servidor inicia o atendimento do cliente 924 no tempo 96.8
# ▼ Servidor termina o atendimento do cliente 924 no tempo 96.9
# ▲ Servidor inicia o atendimento do cliente 925 no tempo 96.9
# ▼ Servidor termina o atendimento do cliente 925 no tempo 97.0
# ▲ Servidor inicia o atendimento do cliente 926 no tempo 97.0
# ▼ Servidor termina o atendimento do cliente 926 no tempo 97.1
# ▲ Servidor inicia o atendimento do cliente 927 no tempo 97.1
# ▼ Servidor termina o atendimento do cliente 927 no tempo 97.2
# ▲ Servidor inicia o atendimento do cliente 928 no tempo 97.2
# ▼ Servidor termina o atendimento do cliente 928 no tempo 97.6
# ▲ Servidor inicia o atendimento do cliente 929 no tempo 97.6
# ▼ Servidor termina o atendimento do cliente 929 no tempo 97.8
# ▲ Servidor inicia o atendimento do cliente 930 no tempo 97.8
# ▼ Servidor termina o atendimento do cliente 930 no tempo 97.8
# ▲ Servidor inicia o atendimento do cliente 931 no tempo 97.8
# ▼ Servidor termina o atendimento do cliente 931 no tempo 97.9
# ▲ Servidor inicia o atendimento do cliente 932 no tempo 97.9
# ▼ Servidor termina o atendimento do cliente 932 no tempo 98.0
# ▲ Servidor inicia o atendimento do cliente 933 no tempo 98.0
# ▼ Servidor termina o atendimento do cliente 933 no tempo 98.0
# ▲ Servidor inicia o atendimento do cliente 934 no tempo 98.0
# ▼ Servidor termina o atendimento do cliente 934 no tempo 98.3
# ▲ Servidor inicia o atendimento do cliente 935 no tempo 98.3
# ▼ Servidor termina o atendimento do cliente 935 no tempo 98.4
# ▲ Servidor inicia o atendimento do cliente 936 no tempo 98.4
# ▼ Servidor termina o atendimento do cliente 936 no tempo 98.4
# ▲ Servidor inicia o atendimento do cliente 937 no tempo 98.4
# ▼ Servidor termina o atendimento do cliente 937 no tempo 98.6
# ▲ Servidor inicia o atendimento do cliente 938 no tempo 98.6
# ▼ Servidor termina o atendimento do cliente 938 no tempo 98.8
# ▲ Servidor inicia o atendimento do cliente 939 no tempo 98.8
# ▼ Servidor termina o atendimento do cliente 939 no tempo 98.8
# ▲ Servidor inicia o atendimento do cliente 940 no tempo 98.8
# ▼ Servidor termina o atendimento do cliente 940 no tempo 98.8
# ▲ Servidor inicia o atendimento do cliente 941 no tempo 98.8
# ▼ Servidor termina o atendimento do cliente 941 no tempo 98.9
# ▲ Servidor inicia o atendimento do cliente 942 no tempo 98.9
# ▼ Servidor termina o atendimento do cliente 942 no tempo 99.0
# ▲ Servidor inicia o atendimento do cliente 943 no tempo 99.0
# ▼ Servidor termina o atendimento do cliente 943 no tempo 99.1
# ▲ Servidor inicia o atendimento do cliente 944 no tempo 99.1
# ▼ Servidor termina o atendimento do cliente 944 no tempo 99.3
# ▲ Servidor inicia o atendimento do cliente 945 no tempo 99.3
# ▼ Servidor termina o atendimento do cliente 945 no tempo 99.4
# ▲ Servidor inicia o atendimento do cliente 946 no tempo 99.4
# ▼ Servidor termina o atendimento do cliente 946 no tempo 99.5
# ▲ Servidor inicia o atendimento do cliente 947 no tempo 99.5
# ▼ Servidor termina o atendimento do cliente 947 no tempo 99.7
# ▲ Servidor inicia o atendimento do cliente 948 no tempo 99.7
# ▼ Servidor termina o atendimento do cliente 948 no tempo 99.8
# ▲ Servidor inicia o atendimento do cliente 949 no tempo 99.8
# ▼ Servidor termina o atendimento do cliente 949 no tempo 99.9
# ▲ Servidor inicia o atendimento do cliente 950 no tempo 99.9
# ▼ Servidor termina o atendimento do cliente 950 no tempo 99.9
# ▲ Servidor inicia o atendimento do cliente 951 no tempo 99.9
# ▼ Servidor termina o atendimento do cliente 951 no tempo 100.4
# ▲ Servidor inicia o atendimento do cliente 952 no tempo 100.4
# ▼ Servidor termina o atendimento do cliente 952 no tempo 100.5
# ▲ Servidor inicia o atendimento do cliente 953 no tempo 100.5
# ▼ Servidor termina o atendimento do cliente 953 no tempo 100.5
# ▲ Servidor inicia o atendimento do cliente 954 no tempo 100.5
# ▼ Servidor termina o atendimento do cliente 954 no tempo 100.5
# ▲ Servidor inicia o atendimento do cliente 955 no tempo 100.5
# ▼ Servidor termina o atendimento do cliente 955 no tempo 100.5
# ▲ Servidor inicia o atendimento do cliente 956 no tempo 100.5
# ▼ Servidor termina o atendimento do cliente 956 no tempo 100.6
# ▲ Servidor inicia o atendimento do cliente 957 no tempo 100.6
# ▼ Servidor termina o atendimento do cliente 957 no tempo 100.6
# ▲ Servidor inicia o atendimento do cliente 958 no tempo 100.6
# ▼ Servidor termina o atendimento do cliente 958 no tempo 100.6
# ▲ Servidor inicia o atendimento do cliente 959 no tempo 100.6
# ▼ Servidor termina o atendimento do cliente 959 no tempo 100.9
# ▲ Servidor inicia o atendimento do cliente 960 no tempo 100.9
# ▼ Servidor termina o atendimento do cliente 960 no tempo 101.0
# ▲ Servidor inicia o atendimento do cliente 961 no tempo 101.0
# ▼ Servidor termina o atendimento do cliente 961 no tempo 101.1
# ▲ Servidor inicia o atendimento do cliente 962 no tempo 101.1
# ▼ Servidor termina o atendimento do cliente 962 no tempo 101.1
# ▲ Servidor inicia o atendimento do cliente 963 no tempo 101.1
# ▼ Servidor termina o atendimento do cliente 963 no tempo 101.1
# ▲ Servidor inicia o atendimento do cliente 964 no tempo 101.1
# ▼ Servidor termina o atendimento do cliente 964 no tempo 101.2
# ▲ Servidor inicia o atendimento do cliente 965 no tempo 101.2
# ▼ Servidor termina o atendimento do cliente 965 no tempo 101.4
# ▲ Servidor inicia o atendimento do cliente 966 no tempo 101.4
# ▼ Servidor termina o atendimento do cliente 966 no tempo 101.5
# ▲ Servidor inicia o atendimento do cliente 967 no tempo 101.5
# ▼ Servidor termina o atendimento do cliente 967 no tempo 101.6
# ▲ Servidor inicia o atendimento do cliente 968 no tempo 101.6
# ▼ Servidor termina o atendimento do cliente 968 no tempo 101.6
# ▲ Servidor inicia o atendimento do cliente 969 no tempo 101.6
# ▼ Servidor termina o atendimento do cliente 969 no tempo 101.7
# ▲ Servidor inicia o atendimento do cliente 970 no tempo 101.7
# ▼ Servidor termina o atendimento do cliente 970 no tempo 101.9
# ▲ Servidor inicia o atendimento do cliente 971 no tempo 101.9
# ▼ Servidor termina o atendimento do cliente 971 no tempo 102.0
# ▲ Servidor inicia o atendimento do cliente 972 no tempo 102.0
# ▼ Servidor termina o atendimento do cliente 972 no tempo 102.1
# ▲ Servidor inicia o atendimento do cliente 973 no tempo 102.1
# ▼ Servidor termina o atendimento do cliente 973 no tempo 102.1
# ▲ Servidor inicia o atendimento do cliente 974 no tempo 102.1
# ▼ Servidor termina o atendimento do cliente 974 no tempo 102.3
# ▲ Servidor inicia o atendimento do cliente 975 no tempo 102.3
# ▼ Servidor termina o atendimento do cliente 975 no tempo 102.4
# ▲ Servidor inicia o atendimento do cliente 976 no tempo 102.4
# ▼ Servidor termina o atendimento do cliente 976 no tempo 102.6
# ▲ Servidor inicia o atendimento do cliente 977 no tempo 102.6
# ▼ Servidor termina o atendimento do cliente 977 no tempo 102.6
# ▲ Servidor inicia o atendimento do cliente 978 no tempo 102.6
# ▼ Servidor termina o atendimento do cliente 978 no tempo 102.8
# ▲ Servidor inicia o atendimento do cliente 979 no tempo 102.8
# ▼ Servidor termina o atendimento do cliente 979 no tempo 103.1
# ▲ Servidor inicia o atendimento do cliente 980 no tempo 103.1
# ▼ Servidor termina o atendimento do cliente 980 no tempo 103.3
# ▲ Servidor inicia o atendimento do cliente 981 no tempo 103.3
# ▼ Servidor termina o atendimento do cliente 981 no tempo 103.4
# ▲ Servidor inicia o atendimento do cliente 982 no tempo 103.4
# ▼ Servidor termina o atendimento do cliente 982 no tempo 103.5
# ▲ Servidor inicia o atendimento do cliente 983 no tempo 103.5
# ▼ Servidor termina o atendimento do cliente 983 no tempo 103.9
# ▲ Servidor inicia o atendimento do cliente 984 no tempo 103.9
# ▼ Servidor termina o atendimento do cliente 984 no tempo 104.1
# ▲ Servidor inicia o atendimento do cliente 985 no tempo 104.1
# ▼ Servidor termina o atendimento do cliente 985 no tempo 104.1
# ▲ Servidor inicia o atendimento do cliente 986 no tempo 104.1
# ▼ Servidor termina o atendimento do cliente 986 no tempo 104.4
# ▲ Servidor inicia o atendimento do cliente 987 no tempo 104.4
# ▼ Servidor termina o atendimento do cliente 987 no tempo 104.4
# ▲ Servidor inicia o atendimento do cliente 988 no tempo 104.4
# ▼ Servidor termina o atendimento do cliente 988 no tempo 104.5
# ▲ Servidor inicia o atendimento do cliente 989 no tempo 104.5
# ▼ Servidor termina o atendimento do cliente 989 no tempo 104.6
# ▲ Servidor inicia o atendimento do cliente 990 no tempo 104.6
# ▼ Servidor termina o atendimento do cliente 990 no tempo 104.8
# ▲ Servidor inicia o atendimento do cliente 991 no tempo 104.8
# ▼ Servidor termina o atendimento do cliente 991 no tempo 104.9
# ▲ Servidor inicia o atendimento do cliente 992 no tempo 104.9
# ▼ Servidor termina o atendimento do cliente 992 no tempo 104.9
# ▲ Servidor inicia o atendimento do cliente 993 no tempo 104.9
# ▼ Servidor termina o atendimento do cliente 993 no tempo 104.9
# ▲ Servidor inicia o atendimento do cliente 994 no tempo 104.9
# ▼ Servidor termina o atendimento do cliente 994 no tempo 105.0
# ▲ Servidor inicia o atendimento do cliente 995 no tempo 105.0
# ▼ Servidor termina o atendimento do cliente 995 no tempo 105.0
# ▲ Servidor inicia o atendimento do cliente 996 no tempo 105.0
# ▼ Servidor termina o atendimento do cliente 996 no tempo 105.0
# ▲ Servidor inicia o atendimento do cliente 997 no tempo 105.0
# ▼ Servidor termina o atendimento do cliente 997 no tempo 105.1
# ▲ Servidor inicia o atendimento do cliente 998 no tempo 105.1
# ▼ Servidor termina o atendimento do cliente 998 no tempo 105.1
# ▲ Servidor inicia o atendimento do cliente 999 no tempo 105.1
# ▼ Servidor termina o atendimento do cliente 999 no tempo 105.2
# ▲ Servidor inicia o atendimento do cliente 1000 no tempo 105.2
# ▼ Servidor termina o atendimento do cliente 1000 no tempo 105.4
