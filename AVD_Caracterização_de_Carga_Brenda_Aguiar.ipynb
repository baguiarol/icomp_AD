# %% [markdown]
# ## Cacterização de Carga

# %% [markdown]
# ##### Objetivo de Experiemento: Explorar os recursos de N smarthphones e permitir que cientitas pudesse investigar interações humanas.
#
# - Podemos modelar essa rede como um grafo com V nós e E arestas.
# - Os nós são enumerados de O a N-1.
# - A primeira linha mostra que o nó 79 iniciou uma conexão CONN com o nó 14 no instante 1.
# - O estabelecimento de uma conexão é indicado por up.
# - A desconexão é indicada por down. A finalização da conexão pode não aparecer no trace.
# - Mesmo que não apareça o down, a conexão é contada pelo up.
# - Se o nó À encontra o nó B pelo menos uma vez, contar apenas uma aresta (E = E + 1).

# %% [markdown]
# - Número de conexões
# - Número de arestas
# - Num médio de conexões por nó
# - Conexões por minuto
# - Tempo total de conexão
# - Tempo médio de conexão
# - Grupo com mais nós conectados (Sugestão: utilizar slots de 3h)
# - Média dos grupos com mais nós conectados
# - Mediana dos grupos com mais nós conectados
# - Número médio de nós conectados
# - Mediana do número de nós conectados
# - Maior grau dos nós por slot
# - Grau médio dos nós por slot
# - Criar uma lista dos contatos e suas durações <br>
# $ (i, j, T_{ij})$, para todo i, j $\in N$
#
# - Densidade do trace <br>
# $ D\:=\:\frac{2\left|E\right|}{\left|V\right|\left(\left|V\right|-1\right)} $

# %%
import sys
import csv
import re
from collections import defaultdict
from datetime import datetime, timedelta
from math import floor
import statistics as st

# %%
FMT_TIMESTAMP = '%d/%m-%H:%M:%S.%f'
TIMESTAMP = 0
FIRST_NODE_ID = 2
SECOND_NODE_ID = 3
TYPE = 4

# %%
funcao_relacao = lambda row: frozenset([row[FIRST_NODE_ID], row[SECOND_NODE_ID]])

def subTimestamps(t1, t2) -> timedelta:
    return timedelta(seconds=float(t1)) - timedelta(seconds=float(t2))

# %%
## A chave é um par; o valor é a quantidade de encontros desse par
encontros = defaultdict(int)
## A chave é um par; o valor é a diferença entre o tempo de `down` pelo de tempo de `up`
duracoes  = defaultdict(str)
qtd_contatos = 0
times_up = defaultdict(str)

diff_reencontros = []
diff_encontros = []
times_encontros = defaultdict(str)

time_up1=''
time_up2=''

dic_no = {}

conexao_no = []

# %%
with open('RealityMining.txt', 'r') as usense_tratado:
    reader = csv.reader(usense_tratado, delimiter=' ')
    for row in reader:
        rel = fn_relacao(row)

        if row[TYPE] == 'up':
            encontros[rel] += 1
            duracoes[rel] = row[TIMESTAMP]

            if encontros[rel] > 1: ## reencontro
                diff_reencontro = subTimestamps(row[TIMESTAMP], times_encontros[rel]).total_seconds()
                diff_reencontros.append(diff_reencontro)
                del times_encontros[rel] ## Manter apenas o tempo do último encontro

            times_encontros[rel] = row[TIMESTAMP]

        else:
            if rel in times_encontros: ## possui um 'up' associado
                if not time_up1:
                    time_up1 = times_encontros[rel]
                else:
                    diff_encontro = subTimestamps(times_encontros[rel], time_up1).total_seconds()
                    diff_encontros.append(diff_encontro)
                    time_up1 = ''

            if type(duracoes[rel]) is str:
                qtd_contatos += 1
                duracoes[rel] = subTimestamps(row[TIMESTAMP], duracoes[rel]).total_seconds()

    usense_tratado.close()
    
    soma_duracoes = sum( duracoes.values() )
    reencontros = {k: v for k, v in encontros.items() if v > 1}
    soma_reencontros = sum( reencontros.values() )
    qtd_reencontros = len(reencontros)
    soma_diff_encontros = sum(diff_encontros)
    soma_diff_reencontros = sum(diff_reencontros)

# %% [markdown]
# ### Número de conexões

# %%
print(qtd_reencontros)
# Out:
# 2569

# %% [markdown]
# ### Número de arestas

# %%
print(len(encontros))
# Out:
# 3085

# %% [markdown]
# ### Num médio de conexões por nó

# %%
print("Numero médio entre conexoes por nó =", len(diff_encontros)/qtd_reencontros)
# Out:
# Numero médio entre conexoes por nó = 19.967302452316076

# %% [markdown]
# ### Conexões por minuto

# %%
 print("Concexoes por minuto =", (soma_diff_encontros/len(diff_encontros))/60, "minutos")
# Out:
# Concexoes por minuto = 1.9775450327510917 minutos

# %% [markdown]
# ### Tempo total de conexão

# %%
print("Tempo total de conexão =", (soma_diff_encontros/qtd_reencontros)/60, "minutos")
# Out:
# Tempo total de conexão = 39.48623978201635 minutos

# %% [markdown]
# ### Grupo com mais nós conectados (Sugestão: utilizar slots de 3h)

# %%
for k, v in encontros.items():
    print(k, v)
# Out:
# frozenset({'14', '79'}) 181
# frozenset({'14', '20'}) 16
# frozenset({'94', '7'}) 50
# frozenset({'7', '80'}) 200
# frozenset({'94', '80'}) 310
# frozenset({'4', '28'}) 8
# frozenset({'94', '28'}) 557
# frozenset({'4', '7'}) 1
# frozenset({'7', '38'}) 61
# frozenset({'28', '38'}) 558
# frozenset({'94', '38'}) 622
# frozenset({'13', '6'}) 27
# frozenset({'13', '28'}) 503
# frozenset({'6', '20'}) 310
# frozenset({'13', '80'}) 605
# frozenset({'79', '15'}) 23
# frozenset({'14', '6'}) 51
# frozenset({'28', '70'}) 39
# frozenset({'28', '68'}) 6
# frozenset({'38', '70'}) 39
# frozenset({'68', '38'}) 12
# frozenset({'94', '68'}) 11
# frozenset({'13', '7'}) 115
# frozenset({'80', '70'}) 67
# frozenset({'7', '70'}) 80
# frozenset({'41', '28'}) 32
# frozenset({'41', '80'}) 9
# frozenset({'13', '70'}) 39
# frozenset({'94', '70'}) 35
# frozenset({'41', '38'}) 17
# frozenset({'38', '56'}) 533
# frozenset({'28', '56'}) 721
# frozenset({'80', '56'}) 318
# frozenset({'88', '28'}) 111
# ...

# %% [markdown]
# ### Média dos grupos com mais nós conectados

# %%
print("Media dos grupos com mais nós conectados =", floor(soma_reencontros/qtd_reencontros), "reencontros")
# Out:
# Media dos grupos com mais nós conectados = 39 reencontros

# %% [markdown]
# ### Mediana dos grupos com mais nós conectados

# %%
mediana = []
for k, v in encontros.items():
    mediana.append(v)

# %%
print("Mediana dos grupos com mais nós conectados =", st.median(mediana), "reencontros")
# Out:
# Mediana dos grupos com mais nós conectados = 7 reencontros

# %% [markdown]
# ### Número médio de nós conectados

# %%
print("Numero medio de nós conectados =", len(encontros)/qtd_contatos)
# Out:
# Numero medio de nós conectados = 0.03587709913011118

# %% [markdown]
# ### Mediana do número de nós conectados

# %%
print("Numero medio de nós conectados =",   st.median(reencontros.values()))
# Out:
# Numero medio de nós conectados = 11

# %% [markdown]
# ### Maior grau dos nós por slot

# %%
max(reencontros.values())
# Out:
# 878

# %% [markdown]
# ### Grau médio dos nós por slot

# %%
st.mean(reencontros.values())
# Out:
# 39.734527053328144

# %% [markdown]
# ### Criar uma lista dos contatos e suas durações <br>
# $ (i, j, T_{ij})$, para todo i, j $\in N$

# %%
print("Lista de encontros", encontros.values(),  duracoes.values())
# Out:
# Lista de encontros dict_values([181, 16, 50, 200, 310, 8, 557, 1, 61, 558, 622, 27, 503, 310, 605, 23, 51, 39, 6, 39, 12, 11, 115, 67, 80, 32, 9, 39, 35, 17, 533, 721, 318, 111, 75, 311, 312, 141, 405, 9, 5, 230, 138, 8, 8, 16, 6, 7, 1, 3, 350, 468, 2, 20, 4, 210, 159, 16, 4, 354, 234, 23, 213, 78, 36, 48, 128, 330, 496, 384, 14, 356, 878, 350, 407, 5, 49, 97, 34, 41, 76, 64, 91, 261, 35, 80, 538, 167, 648, 473, 612, 18, 24, 46, 261, 123, 580, 259, 634, 541, 55, 11, 28, 65, 378, 533, 52, 233, 95, 6, 21, 431, 13, 47, 14, 12, 16, 40, 5, 19, 217, 45, 2, 102, 177, 351, 175, 146, 382, 121, 145, 70, 29, 35, 204, 171, 73, 146, 74, 77, 65, 53, 87, 366, 8, 7, 145, 39, 13, 15, 151, 47, 116, 320, 271, 297, 296, 116, 344, 248, 235, 101, 81, 74, 86, 36, 120, 103, 103, 121, 9, 2, 8, 278, 93, 49, 232, 192, 146, 67, 113, 504, 100, 2, 1, 177, 74, 18, 43, 54, 15, 71, 4, 3, 13, 17, 105, 68, 12, 7, 6, 56, 5, 9, 100, 24, 23, 154, 55, 19, 23, 304, 184, 18, 91, 123, 8, 19, 6, 46, 29, 27, 49, 12, 6, 4, 33, 
# ...

# %% [markdown]
# ### Densidade do trace <br>
# $ D\:=\:\frac{2\left|E\right|}{\left|V\right|\left(\left|V\right|-1\right)} $

# %%
print(len(duracoes.values()))
print(len(encontros.items()))
# Out:
# 3085
# 3085

# %%
# def densidade():
d = (2*len(encontros.items()))/(len(reencontros.values()) - (len(reencontros.values())-1))

# %%
print("Densidade do trace: ",d)
# Out:
# Densidade do trace:  6170.0
